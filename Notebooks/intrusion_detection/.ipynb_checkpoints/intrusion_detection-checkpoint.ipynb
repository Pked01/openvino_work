# %%
from __future__ import print_function
import sys
import os
from argparse import ArgumentParser, SUPPRESS
import cv2,threading
import time
import logging as log
from openvino.inference_engine import IENetwork, IEPlugin
import matplotlib.pyplot as plt
import ipywidgets as widgets
import IPython.display as Disp

# %%
model_path = '/home/prateek/prateek_space/intel_model_dump/intel/person-detection-retail-0013/FP32/person-detection-retail-0013.xml'
channel = 'rtsp://user:operator@123@10.36.12.113:554/Streaming/Channels/801/'
threshold = .5
cpu_extension = '../build_demos/intel64/Release/lib/libcpu_extension.so'
device = 'CPU'

# %%
class bbox_select():
    # %matplotlib notebook 


    def __init__(self,im):
        self.im = im
        self.selected_points = []
        self.fig,ax = plt.subplots()
        self.img = ax.imshow(self.im.copy())
        self.ka = self.fig.canvas.mpl_connect('button_press_event', self.onclick)
        disconnect_button = widgets.Button(description="Disconnect mpl")
        Disp.display(disconnect_button)
        disconnect_button.on_click(self.disconnect_mpl)


        
    def poly_img(self,img,pts):
        pts = np.array(pts, np.int32)
        pts = pts.reshape((-1,1,2))
        cv2.polylines(img,[pts],True,(0,255,255),4)
        return img

    def onclick(self, event):
    #display(str(event))
        self.selected_points.append([event.xdata,event.ydata])
        if len(self.selected_points)>1:
            self.fig
            self.img.set_data(self.poly_img(self.im.copy(),self.selected_points))
    def disconnect_mpl(self,_):
        self.fig.canvas.mpl_disconnect(self.ka)

# %%
def poly_intersection_mask(img,pt1,pt2):
    """
    returns area masked
    """
    img_mask = np.zeros(img.shape,np.uint8)
    mask1 = cv2.fillPoly(img_mask.copy(),np.array([pt1],int),[1,1,1])
    mask2 = cv2.fillPoly(img_mask.copy(),np.array([pt2],int),[1,1,1])
    intersection = cv2.bitwise_and(mask1,mask2)
    return (intersection.sum()/mask1.sum(),intersection.sum()/mask2.sum())

# %%
plugin = IEPlugin(device='CPU')
if cpu_extension and 'CPU' in device:
    plugin.add_cpu_extension(cpu_extension)

log.info("Reading IR...")
net = IENetwork(model=model_path, weights=os.path.splitext(model_path)[0] + ".bin")

# %%
if device == "CPU":
    supported_layers = plugin.get_supported_layers(net)
    not_supported_layers = [l for l in net.layers.keys() if l not in supported_layers]
    if len(not_supported_layers) != 0:
        log.error("Following layers are not supported by the plugin for specified device {}:\n {}".
                  format(plugin.device, ', '.join(not_supported_layers)))
        log.error("Please try to specify cpu extensions library path in demo's command line parameters using -l "
                  "or --cpu_extension command line argument")
        sys.exit(1)

# %%
assert len(net.inputs.keys()) == 1, "Demo supports only single input topologies"
assert len(net.outputs) == 1, "Demo supports only single output topologies"
input_blob = next(iter(net.inputs))
out_blob = next(iter(net.outputs))
log.info("Loading IR to the plugin...")
exec_net = plugin.load(network=net, num_requests=2)
# Read and pre-process input image
n, c, h, w = net.inputs[input_blob].shape
del net

# %%
channel = "/media/prateek/prateek_space/dataset/taloja_annealing_view/Embedded Net DVR_10.36.12.122_16_20190521084551_20190521084619_1558435398567.mp4"

# %%
cap = cv2.VideoCapture(channel)
ret,frame = cap.read()
bs = bbox_select(cv2.cvtColor(frame[:,:,:],cv2.COLOR_BGR2RGB))
font = cv2.FONT_HERSHEY_SIMPLEX
# Out:
# <img src="data:image/png;base64,..." width="640">
# Button(description='Disconnect mpl', style=ButtonStyle())

# %%
cap = cv2.VideoCapture(video_url)
cv2.namedWindow('preview',cv2.WINDOW_NORMAL)
write_video = True
if write_video:
    out = None
    
while True:
#     print(count)
#     count += 1
    Disp.clear_output(wait=True)
    
    for i in range(3):
        cap.read()
    ret, image = cap.read()
    image = image[:,500:,:]
    if not ret:
        break
    # copy to draw on
    draw = image.copy()
    draw = cv2.cvtColor(draw, cv2.COLOR_BGR2RGB)

    # preprocess image for network
    image = preprocess_image(image)
    image, scale = resize_image(image)

    # process image
    start = time.time()
    boxes, scores, labels = model.predict_on_batch(np.expand_dims(image, axis=0))
    print("processing time: ", time.time() - start)

    # correct for image scale
    boxes /= scale

    # visualize detections
    for box, score, label in zip(boxes[0], scores[0], labels[0]):
        # scores are sorted so we can break
        
        draw = bs.poly_img(draw,bs.selected_points)
        if score < 0.4:
            break
#         print(label)
        color = label_color(label)

#         b = box.astype(int)
#         draw_box(draw, b, color=color)
        
        name = labels_to_names[label]
        if name in search_labels:
            b = box.astype(int)
            draw[b[1]:b[3],b[0]:b[2]]
            draw_box(draw, b, color=color)
            caption = "{} {:.3f}".format(labels_to_names[label], score)
            draw_caption(draw, b, caption)
            intersection = poly_intersection_mask(draw,bs.selected_points,[[b[0],b[1]],[b[2],b[1]],[b[2],b[3]],[b[0],b[3]]])[1]
            if intersection >.1:
                draw = cv2.putText(draw,'intrusion',(draw.shape[1]-300,100), font,2,(255,0,0),2,cv2.LINE_AA)
            
    draw = cv2.cvtColor(draw, cv2.COLOR_RGB2BGR)
#     out.write(draw)
    cv2.imshow('preview',draw)
    k = cv2.waitKey(1)
    
    if out is None:
        out = cv2.VideoWriter('output_vids/'+datetime.datetime.now().strftime("%Y_%m_%d_%H_%M_%S_")+os.path.basename(video_url)+'_out.mp4',cv2.VideoWriter_fourcc('M','J','P','G'), 20, (draw.shape[1],draw.shape[0]))
    out.write(draw)
    if k==27:
        break
#     plt.figure(figsize=(15, 15))
#     plt.axis('off')
#     plt.imshow(draw)
#     plt.show()

out.release()
cap.release()
cv2.destroyAllWindows()
